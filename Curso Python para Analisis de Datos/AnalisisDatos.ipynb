# %% [markdown]
# # Curso Python para Analisis de Datos
#
# ## Clase 1 - Preparacion del entorno
#
# En esta primera clase se dejo listo el entorno de trabajo para comenzar con analisis de datos en Python.
#
# - Instalacion de Python 3.12.
# - Creacion de un entorno virtual local.
# - Instalacion de `pandas`, `numpy`, `matplotlib` y `seaborn`.
# - Configuracion inicial para trabajar con notebooks y graficas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('pandas:', pd.__version__)
print('numpy:', np.__version__)
print('matplotlib:', plt.matplotlib.__version__)
print('seaborn:', sns.__version__)
